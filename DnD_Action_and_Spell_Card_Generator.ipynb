# %% [markdown]
# <a href="https://colab.research.google.com/github/damman01/dnd-tools/blob/main/DnD_Action_and_Spell_Card_Generator.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from weasyprint import HTML

html_content = """
<!DOCTYPE html>
<html>
<head>
<meta charset="utf-8">
<style>
@page {
    size: 70mm 120mm;
    margin: 4mm;
}
body {
    font-family: 'Helvetica Neue', Helvetica, Arial, sans-serif;
    margin: 0;
    padding: 0;
    box-sizing: border-box;
}
*, *::before, *::after { box-sizing: border-box; }

.card {
    width: 100%;
    height: 100%;
    border-radius: 8px;
    position: relative;
    overflow: hidden;
    page-break-after: always;
}

.red { background-color: #fffafa; border: 2px solid #8b0000; }
.blue { background-color: #f8fbff; border: 2px solid #003399; }
.green { background-color: #f6fff6; border: 2px solid #006400; }
.gold { background-color: #fffdf5; border: 2px solid #b8860b; }

.header {
    color: white;
    padding: 6px 4px;
    text-align: center;
    font-weight: bold;
    font-size: 10pt;
    text-transform: uppercase;
}
.red .header { background-color: #b30000; border-bottom: 2px solid #8b0000; }
.blue .header { background-color: #0044cc; border-bottom: 2px solid #003399; }
.green .header { background-color: #008000; border-bottom: 2px solid #006400; }
.gold .header { background-color: #daa520; border-bottom: 2px solid #b8860b; }

.content {
    padding: 6px;
    color: #222;
    display: flex;
    flex-direction: column;
    height: calc(100% - 30px);
}

.stat-row {
    margin-bottom: 4px;
    font-size: 8pt;
    line-height: 1.2;
}
.stat-label {
    font-weight: bold;
    text-transform: uppercase;
    font-size: 7pt;
    color: #555;
    display: inline-block;
    width: 23mm;
}

.effect {
    background: #fff;
    border-radius: 4px;
    padding: 6px;
    margin-top: 4px;
    margin-bottom: 6px;
    font-size: 8pt;
    font-weight: bold;
    box-shadow: 0 1px 2px rgba(0,0,0,0.1);
}
.red .effect { border-left: 4px solid #b30000; }
.blue .effect { border-left: 4px solid #0044cc; }
.green .effect { border-left: 4px solid #008000; }
.gold .effect { border-left: 4px solid #daa520; }

.fluff {
    background: rgba(0,0,0,0.03);
    padding: 6px;
    border-radius: 4px;
    font-family: 'Times New Roman', serif;
    font-size: 8pt;
    text-align: center;
    font-style: italic;
    color: #333;
    border: 1px solid rgba(0,0,0,0.05);
    margin-bottom: 6px;
}

.tactic-title {
    font-size: 7.5pt;
    font-weight: bold;
    color: #444;
    margin-bottom: 2px;
    text-transform: uppercase;
}
.tactic {
    font-size: 8pt;
    color: #333;
    line-height: 1.2;
    flex-grow: 1;
}

.tracker-container {
    display: flex;
    align-items: center;
    margin-top: 2px;
}
.tracker-label {
    font-size: 7.5pt;
    font-weight: bold;
    margin-right: 6px;
    color: #555;
}
.circle {
    display: inline-block;
    width: 10px;
    height: 10px;
    border: 1px solid #555;
    border-radius: 50%;
    background-color: white;
    margin-right: 3px;
    box-shadow: inset 0 1px 2px rgba(0,0,0,0.1);
}

.tracker-row {
    margin-bottom: 8px;
    background: #fff;
    padding: 6px;
    border-radius: 4px;
    border-left: 4px solid #daa520;
    box-shadow: 0 1px 2px rgba(0,0,0,0.1);
}
.tracker-row .tracker-label {
    display: block;
    margin-bottom: 4px;
    font-size: 8pt;
    color: #222;
}
</style>
</head>
<body>
"""

cards = [
    {
        "name": "Sternenform: Schütze",
        "type": "red",
        "cost": "Bonusaktion",
        "range": "18 Meter",
        "effect": "Du schießt einen leuchtenden Pfeil ab. Würfle den W20 (+7). Bei einem Treffer machst du 1W8 + 4 gleißenden Schaden.",
        "fluff": "Meine Sternenkarte beginnt hell zu leuchten, und die Sternbilder formen einen schimmernden Bogen in meinen Pfoten.",
        "tactic": "Perfekt, um jede Runde zusätzlich Schaden auszuteilen, nachdem du bereits angegriffen oder einen Zauber gewirkt hast.",
        "trackers": 0
    },
    {
        "name": "Leitendes Geschoss",
        "type": "red",
        "cost": "Aktion",
        "range": "36 Meter",
        "effect": "Wirf den W20 (+7). Trifft der Blitz, machst du 4W6 Schaden. Der nächste Angriff gegen dieses Ziel hat zudem Vorteil!",
        "fluff": "Ein greller Sternenblitz schießt aus meiner Karte und heftet sich flirrend an den Körper meines Feindes.",
        "tactic": "Super gegen dicke Bosse! Danach direkt deine Sternenform-Bonusaktion für einen garantierten Treffer nutzen.",
        "trackers": 4,
        "tracker_label": "Gratis / Tag:"
    },
    {
        "name": "Hasensprung",
        "type": "blue",
        "cost": "Bonusaktion",
        "range": "4,5 Meter (Sprung)",
        "effect": "Du springst blitzschnell 4,5 Meter in eine beliebige Richtung. Dabei provozierst du KEINE Gelegenheitsangriffe!",
        "fluff": "Bevor der Feind zuschlagen kann, spanne ich meine kräftigen Hasenbeine an und bin schon außer Reichweite.",
        "tactic": "Die perfekte Flucht, wenn ein Oger oder Ork direkt vor dir steht und du unbeschadet wegkommen musst.",
        "trackers": 3,
        "tracker_label": "Pro Tag:"
    },
    {
        "name": "Glückliche Pfoten",
        "type": "blue",
        "cost": "Reaktion",
        "range": "Du selbst",
        "effect": "Wenn du einen Geschicklichkeits-Rettungswurf knapp nicht schaffst, würfelst du 1W4 und rechnest ihn einfach dazu.",
        "fluff": "Meine geschärften Instinkte kicken im allerletzten Moment rein – ich ducke mich knapp unter dem tödlichen Schlag hindurch!",
        "tactic": "Dein Lebensretter! Nutze es, um Feuerbällen, Drachenodem oder versteckten Fallen gerade noch auszuweichen.",
        "trackers": 0
    },
    {
        "name": "Heilendes Wort",
        "type": "green",
        "cost": "Bonusaktion",
        "range": "18 Meter",
        "effect": "Ein Verbündeter heilt 1W4 + 4 Trefferpunkte.",
        "fluff": "Ich rufe die tröstende Kraft der Sterne an. Eine sanfte, leuchtende Brise umhüllt und heilt meine Freunde.",
        "tactic": "Rette Nibu oder Oden, wenn sie auf 0 Leben fallen, während du sicher auf Distanz bleibst. Kostet Zauberplätze!",
        "trackers": 0
    },
    {
        "name": "Dornenpeitsche",
        "type": "red",
        "cost": "Aktion",
        "range": "9 Meter",
        "effect": "Nahkampfangriff auf Distanz! Würfle W20 (+7). Macht 1W6 Stichschaden und zieht das Ziel 3 Meter zu dir heran.",
        "fluff": "Aus meiner Pfote schießt eine magische Ranke, wickelt sich brutal um den Feind und reißt ihn von den Beinen.",
        "tactic": "Zieh Gegner von verletzten Verbündeten weg oder zerre sie in Umweltgefahren hinein. (Unendlich oft nutzbar)",
        "trackers": 0
    }
]

for card in cards:
    tracker_html = ""
    if card.get("trackers", 0) > 0:
        circles = "".join(['<div class="circle"></div>' for _ in range(card["trackers"])])
        tracker_html = f'''
        <div class="tracker-container">
            <span class="tracker-label">{card["tracker_label"]}</span>
            {circles}
        </div>
        '''

    html_content += f"""
    <div class="card {card['type']}">
        <div class="header">{card['name']}</div>
        <div class="content">
            <div class="stat-row"><span class="stat-label">Kosten:</span> {card['cost']}</div>
            <div class="stat-row"><span class="stat-label">Reichweite:</span> {card['range']}</div>
            {tracker_html}

            <div class="effect">
                {card['effect']}
            </div>

            <div class="fluff">
                "{card['fluff']}"
            </div>

            <div class="tactic-title">Wann man es nutzt:</div>
            <div class="tactic">{card['tactic']}</div>
        </div>
    </div>
    """

html_content += """
    <div class="card gold">
        <div class="header">Ressourcen & Zauber</div>
        <div class="content">
            <div class="fluff" style="margin-bottom: 10px;">
                "Die Sterne leiten mich, doch auch meine Kraft hat ihre Grenzen. Ein kurzer Moment der Rast gibt mir neue Energie."
            </div>

            <div class="tracker-row">
                <span class="tracker-label">Zauberplätze Grad 1 (Täglich)</span>
                <div class="circle"></div><div class="circle"></div><div class="circle"></div><div class="circle"></div>
            </div>

            <div class="tracker-row">
                <span class="tracker-label">Zauberplätze Grad 2 (Täglich)</span>
                <div class="circle"></div><div class="circle"></div><div class="circle"></div>
            </div>

            <div class="tracker-row">
                <span class="tracker-label">Zauberplätze Grad 3 (Täglich)</span>
                <div class="circle"></div><div class="circle"></div>
            </div>

            <div class="tracker-row">
                <span class="tracker-label">Sternenform / Tiergestalt (Pro Rast)</span>
                <div class="circle"></div><div class="circle"></div>
            </div>
        </div>
    </div>
"""

html_content += """
</body>
</html>
"""

with open("wiwaka_karten_v2.html", "w", encoding="utf-8") as f:
    f.write(html_content)

HTML("wiwaka_karten_v2.html").write_pdf("Wiwaka_Anfaenger_Lernkarten_v2.pdf")
print("PDF created successfully!")

# %%
import os
from weasyprint import HTML

html_content = """
<!DOCTYPE html>
<html>
<head>
<meta charset="utf-8">
<style>
@page {
    size: 70mm 120mm;
    margin: 4mm;
}
body {
    font-family: 'Helvetica Neue', Helvetica, Arial, sans-serif;
    margin: 0;
    padding: 0;
    box-sizing: border-box;
}
*, *::before, *::after { box-sizing: border-box; }

.card {
    width: 100%;
    height: 100%;
    border-radius: 8px;
    position: relative;
    overflow: hidden;
    page-break-after: always;
}

.red { background-color: #fffafa; border: 2px solid #8b0000; }
.blue { background-color: #f8fbff; border: 2px solid #003399; }
.green { background-color: #f6fff6; border: 2px solid #006400; }
.gold { background-color: #fffdf5; border: 2px solid #b8860b; }

.header {
    color: white;
    padding: 6px 4px;
    text-align: center;
    font-weight: bold;
    font-size: 10pt;
    text-transform: uppercase;
}
.red .header { background-color: #b30000; border-bottom: 2px solid #8b0000; }
.blue .header { background-color: #0044cc; border-bottom: 2px solid #003399; }
.green .header { background-color: #008000; border-bottom: 2px solid #006400; }
.gold .header { background-color: #daa520; border-bottom: 2px solid #b8860b; }

.content {
    padding: 6px;
    color: #222;
    display: flex;
    flex-direction: column;
    height: calc(100% - 30px);
}

.stat-row {
    margin-bottom: 4px;
    font-size: 8pt;
    line-height: 1.2;
}
.stat-label {
    font-weight: bold;
    text-transform: uppercase;
    font-size: 7pt;
    color: #555;
    display: inline-block;
    width: 23mm;
}

.effect {
    background: #fff;
    border-radius: 4px;
    padding: 6px;
    margin-top: 4px;
    margin-bottom: 6px;
    font-size: 8pt;
    font-weight: bold;
    box-shadow: 0 1px 2px rgba(0,0,0,0.1);
}
.red .effect { border-left: 4px solid #b30000; }
.blue .effect { border-left: 4px solid #0044cc; }
.green .effect { border-left: 4px solid #008000; }
.gold .effect { border-left: 4px solid #daa520; }

.fluff {
    background: rgba(0,0,0,0.03);
    padding: 6px;
    border-radius: 4px;
    font-family: 'Times New Roman', serif;
    font-size: 8pt;
    text-align: center;
    font-style: italic;
    color: #333;
    border: 1px solid rgba(0,0,0,0.05);
    margin-bottom: 6px;
}

.tactic-title {
    font-size: 7.5pt;
    font-weight: bold;
    color: #444;
    margin-bottom: 2px;
    text-transform: uppercase;
}
.tactic {
    font-size: 8pt;
    color: #333;
    line-height: 1.2;
    flex-grow: 1;
}

.tracker-container {
    display: flex;
    align-items: center;
    margin-top: 2px;
}
.tracker-label {
    font-size: 7.5pt;
    font-weight: bold;
    margin-right: 6px;
    color: #555;
}
.circle {
    display: inline-block;
    width: 10px;
    height: 10px;
    border: 1px solid #555;
    border-radius: 50%;
    background-color: white;
    margin-right: 3px;
    box-shadow: inset 0 1px 2px rgba(0,0,0,0.1);
}

.tracker-row {
    margin-bottom: 8px;
    background: #fff;
    padding: 6px;
    border-radius: 4px;
    border-left: 4px solid #daa520;
    box-shadow: 0 1px 2px rgba(0,0,0,0.1);
}
.tracker-row .tracker-label {
    display: block;
    margin-bottom: 4px;
    font-size: 8pt;
    color: #222;
}
</style>
</head>
<body>
"""

cards = [
    {
        "name": "Sternenform: Schütze",
        "type": "red",
        "cost": "Bonusaktion",
        "range": "18 Meter",
        "effect": "Du schießt einen leuchtenden Pfeil ab. Würfle den W20 (+7). Bei einem Treffer machst du 1W8 + 4 gleißenden Schaden.",
        "fluff": "Meine Sternenkarte beginnt hell zu leuchten, und die Sternbilder formen einen schimmernden Bogen in meinen Pfoten.",
        "tactic": "Perfekt, um jede Runde zusätzlich Schaden auszuteilen, nachdem du bereits angegriffen oder einen Zauber gewirkt hast.",
        "trackers": 0
    },
    {
        "name": "Leitendes Geschoss",
        "type": "red",
        "cost": "Aktion",
        "range": "36 Meter",
        "effect": "Wirf den W20 (+7). Trifft der Blitz, machst du 4W6 Schaden. Der nächste Angriff gegen dieses Ziel hat zudem Vorteil!",
        "fluff": "Ein greller Sternenblitz schießt aus meiner Karte und heftet sich flirrend an den Körper meines Feindes.",
        "tactic": "Super gegen dicke Bosse! Danach direkt deine Sternenform-Bonusaktion für einen garantierten Treffer nutzen.",
        "trackers": 4,
        "tracker_label": "Gratis / Tag:"
    },
    {
        "name": "Hasensprung",
        "type": "blue",
        "cost": "Bonusaktion",
        "range": "4,5 Meter (Sprung)",
        "effect": "Du springst blitzschnell 4,5 Meter in eine beliebige Richtung. Dabei provozierst du KEINE Gelegenheitsangriffe!",
        "fluff": "Bevor der Feind zuschlagen kann, spanne ich meine kräftigen Hasenbeine an und bin schon außer Reichweite.",
        "tactic": "Die perfekte Flucht, wenn ein Oger oder Ork direkt vor dir steht und du unbeschadet wegkommen musst.",
        "trackers": 3,
        "tracker_label": "Pro Tag:"
    },
    {
        "name": "Glückliche Pfoten",
        "type": "blue",
        "cost": "Reaktion",
        "range": "Du selbst",
        "effect": "Wenn du einen Geschicklichkeits-Rettungswurf knapp nicht schaffst, würfelst du 1W4 und rechnest ihn einfach dazu.",
        "fluff": "Meine geschärften Instinkte kicken im allerletzten Moment rein – ich ducke mich knapp unter dem tödlichen Schlag hindurch!",
        "tactic": "Dein Lebensretter! Nutze es, um Feuerbällen, Drachenodem oder versteckten Fallen gerade noch auszuweichen.",
        "trackers": 0
    },
    {
        "name": "Heilendes Wort",
        "type": "green",
        "cost": "Bonusaktion",
        "range": "18 Meter",
        "effect": "Ein Verbündeter heilt 1W4 + 4 Trefferpunkte.",
        "fluff": "Ich rufe die tröstende Kraft der Sterne an. Eine sanfte, leuchtende Brise umhüllt und heilt meine Freunde.",
        "tactic": "Rette Nibu oder Oden, wenn sie auf 0 Leben fallen, während du sicher auf Distanz bleibst. Kostet Zauberplätze!",
        "trackers": 0
    },
    {
        "name": "Dornenpeitsche",
        "type": "red",
        "cost": "Aktion",
        "range": "9 Meter",
        "effect": "Nahkampfangriff auf Distanz! Würfle W20 (+7). Macht 1W6 Stichschaden und zieht das Ziel 3 Meter zu dir heran.",
        "fluff": "Aus meiner Pfote schießt eine magische Ranke, wickelt sich brutal um den Feind und reißt ihn von den Beinen.",
        "tactic": "Zieh Gegner von verletzten Verbündeten weg oder zerre sie in Umweltgefahren hinein. (Unendlich oft nutzbar)",
        "trackers": 0
    }
]

for card in cards:
    tracker_html = ""
    if card.get("trackers", 0) > 0:
        circles = "".join(['<div class="circle"></div>' for _ in range(card["trackers"])])
        tracker_html = f'''
        <div class="tracker-container">
            <span class="tracker-label">{card["tracker_label"]}</span>
            {circles}
        </div>
        '''

    html_content += f"""
    <div class="card {card['type']}">
        <div class="header">{card['name']}</div>
        <div class="content">
            <div class="stat-row"><span class="stat-label">Kosten:</span> {card['cost']}</div>
            <div class="stat-row"><span class="stat-label">Reichweite:</span> {card['range']}</div>
            {tracker_html}

            <div class="effect">
                {card['effect']}
            </div>

            <div class="fluff">
                "{card['fluff']}"
            </div>

            <div class="tactic-title">Wann man es nutzt:</div>
            <div class="tactic">{card['tactic']}</div>
        </div>
    </div>
    """

html_content += """
    <div class="card gold">
        <div class="header">Ressourcen & Zauber</div>
        <div class="content">
            <div class="fluff" style="margin-bottom: 10px;">
                "Die Sterne leiten mich, doch auch meine Kraft hat ihre Grenzen. Ein kurzer Moment der Rast gibt mir neue Energie."
            </div>

            <div class="tracker-row">
                <span class="tracker-label">Zauberplätze Grad 1 (Täglich)</span>
                <div class="circle"></div><div class="circle"></div><div class="circle"></div><div class="circle"></div>
            </div>

            <div class="tracker-row">
                <span class="tracker-label">Zauberplätze Grad 2 (Täglich)</span>
                <div class="circle"></div><div class="circle"></div><div class="circle"></div>
            </div>

            <div class="tracker-row">
                <span class="tracker-label">Zauberplätze Grad 3 (Täglich)</span>
                <div class="circle"></div><div class="circle"></div>
            </div>

            <div class="tracker-row">
                <span class="tracker-label">Sternenform / Tiergestalt (Pro Rast)</span>
                <div class="circle"></div><div class="circle"></div>
            </div>
        </div>
    </div>
"""

html_content += """
</body>
</html>
"""

html_file = "wiwaka_karten_v2.html"
pdf_file = "Wiwaka_Anfaenger_Lernkarten_v2.pdf"

with open(html_file, "w", encoding="utf-8") as f:
    f.write(html_content)

HTML(html_file).write_pdf(pdf_file)
print(f"Created {pdf_file}")

# %% [markdown]
# Hier ist die aktualisierte und druckfertige PDF-Datei mit den erweiterten Anfänger-Lernkarten für Wiwaka:
# [file-tag: Wiwaka_Anfaenger_Lernkarten_v2.pdf]
#
# Die Karten wurden gemäss den Vorgaben wie folgt optimiert:
#
# * **Fluff-Texte verschoben:** Der atmosphärische Text in der Ich-Perspektive steht nun direkt über dem Taktik-Teil und fügt sich natürlich in den Lesefluss ein, ohne den Platz auf der Karte zu sprengen.
# * **Ressourcen-Zähler auf den Karten:** Bei den Aktionen mit begrenzten Anwendungen sind nun kleine Kreise zum Abstreichen direkt eingefügt. *Leitendes Geschoss* hat vier Tracker-Kreise für die gratis Anwendungen erhalten, und *Hasensprung* wurde mit drei Kreisen versehen.
# * **Neue Ressourcen-Karte:** Das Set enthält nun eine zusätzliche "Ressourcen & Zauber"-Karte im eigenen Design. Darauf befinden sich kleine Kreise zum Tracken der Zauberplätze für Grad 1, 2 und 3 als Druidin der Stufe 5 sowie die zwei Einsätze für die *Sternenform* bzw. *Tiergestalt*.
#
# So hat man am Spieltisch nicht nur die Regeln kompakt griffbereit, sondern kann auch den Verbrauch von Zauberplätzen und Spezialfähigkeiten ganz einfach mit einem abwischbaren Stift oder kleinen Markern verwalten.
